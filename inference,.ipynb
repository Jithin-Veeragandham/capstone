ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jithi\OneDrive\Desktop\VsCode\capstone\inference,.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jithi/OneDrive/Desktop/VsCode/capstone/inference%2C.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from ultralytics import YOLO
#       <a href='vscode-notebook-cell:/c%3A/Users/jithi/OneDrive/Desktop/VsCode/capstone/inference%2C.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> model = YOLO("C:\\Users\\jithi\\Downloads\\yolov8n.pt")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jithi/OneDrive/Desktop/VsCode/capstone/inference%2C.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> model.predict(source="0",show=True,conf=0.5)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\model.py:246, in Model.predict(self, source, stream, predictor, **kwargs)
#     244 if len and hasattr(self.predictor, 'set_prompts'):
#     245     self.predictor.set_prompts(prompts)
# --> 246 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:197, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     195     return self.stream_inference(source, model, *args, **kwargs)
#     196 else:
# --> 197     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\utils\_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:138, in BasePredictor.inference(self, im, *args, **kwargs)
#     135 def inference(self, im, *args, **kwargs):
#     136     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     137                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 138     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\autobackend.py:334, in AutoBackend.forward(self, im, augment, visualize)
#     331     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     333 if self.pt or self.nn_module:  # PyTorch
# --> 334     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     335 elif self.jit:  # TorchScript
#     336     y = self.model(im)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\modules\block.py:182, in C2f.forward(self, x)
#     180 y = list(self.cv1(x).chunk(2, 1))
#     181 y.extend(m(y[-1]) for m in self.m)
# --> 182 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\modules\conv.py:42, in Conv.forward_fuse(self, x)
#      40 def forward_fuse(self, x):
#      41     """Perform transposed convolution of 2D data."""
# ---> 42     return self.act(self.conv(x))
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
from ultralytics import YOLO

# Load YOLO model
model = YOLO("C:\\Users\\jithi\\Downloads\\yolov8Zip\\weights\\best.pt")
results = model.track(source="https://youtu.be/Zgi9g1ksQHc", show=True, tracker="bytetrack.yaml")
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Collecting lapx>=0.5.2
#   Downloading lapx-0.5.4-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: Cython>=0.29.32 in c:\users\jithi\.conda\envs\tensorflow_oiio\lib\site-packages (from lapx>=0.5.2) (0.29.32)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\jithi\.conda\envs\tensorflow_oiio\lib\site-packages (from lapx>=0.5.2) (1.25.2)
# Installing collected packages: lapx
# Successfully installed lapx-0.5.4
#
# requirements: AutoUpdate success  7.9s, installed 1 package: ['lapx>=0.5.2']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# requirements: Ultralytics requirements ['pafy', 'youtube_dl==2020.12.2'] not found, attempting AutoUpdate...
# Collecting pafy
#   Downloading pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Collecting youtube_dl==2020.12.2
#   Downloading youtube_dl-2020.12.2-py2.py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\model.py:269, in Model.track(self, source, stream, persist, **kwargs)
#     267 kwargs['conf'] = conf
#     268 kwargs['mode'] = 'track'
# --> 269 return self.predict(source=source, stream=stream, **kwargs)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\model.py:246, in Model.predict(self, source, stream, predictor, **kwargs)
#     244 if len and hasattr(self.predictor, 'set_prompts'):
#     245     self.predictor.set_prompts(prompts)
# --> 246 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:197, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     195     return self.stream_inference(source, model, *args, **kwargs)
#     196 else:
# --> 197     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\utils\_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:138, in BasePredictor.inference(self, im, *args, **kwargs)
#     135 def inference(self, im, *args, **kwargs):
#     136     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     137                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 138     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\autobackend.py:334, in AutoBackend.forward(self, im, augment, visualize)
#     331     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     333 if self.pt or self.nn_module:  # PyTorch
# --> 334     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     335 elif self.jit:  # TorchScript
#     336     y = self.model(im)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\modules\conv.py:297, in Concat.forward(self, x)
#     295 def forward(self, x):
#     296     """Forward pass for the YOLOv8 mask Proto module."""
# --> 297     return torch.cat(x, self.d)
#
# KeyboardInterrupt:

# %%
import cv2
from ultralytics import YOLO

# Load YOLO model
model = YOLO("C:\\Users\\jithi\\Downloads\\yolov8Zip\\weights\\best.pt")
results = model.track(source="https://youtu.be/Zgi9g1ksQHc", show=True, tracker="bytetrack.yaml")
# Open the default camera (camera index 0)
cap = cv2.VideoCapture(0)

while cap.isOpened():
    success, frame = cap.read()
    if success:
        # Perform YOLO inference on the frame
        results = model(frame)
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop when 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break

# Release the camera and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 167.0ms
# Speed: 4.5ms preprocess, 167.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.6ms
# Speed: 2.5ms preprocess, 156.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.2ms
# Speed: 2.5ms preprocess, 135.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.8ms
# Speed: 2.0ms preprocess, 137.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.6ms
# Speed: 3.3ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.3ms
# Speed: 2.0ms preprocess, 135.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.7ms
# Speed: 3.0ms preprocess, 131.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.5ms
# Speed: 2.5ms preprocess, 130.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dog, 125.9ms
# Speed: 3.0ms preprocess, 125.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dog, 154.3ms
# Speed: 3.0ms preprocess, 154.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 141.6ms
# Speed: 2.0ms preprocess, 141.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.8ms
# Speed: 3.0ms preprocess, 123.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dog, 163.4ms
# Speed: 8.6ms preprocess, 163.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.4ms
# Speed: 3.0ms preprocess, 123.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.8ms
# Speed: 2.6ms preprocess, 133.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.2ms
# Speed: 2.5ms preprocess, 128.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dog, 125.7ms
# Speed: 3.0ms preprocess, 125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.9ms
# Speed: 2.0ms preprocess, 122.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.2ms
# Speed: 3.0ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.2ms
# Speed: 3.0ms preprocess, 131.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.1ms
# Speed: 3.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117
8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.2ms
# Speed: 2.0ms preprocess, 118.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.7ms
# Speed: 2.0ms preprocess, 120.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.4ms
# Speed: 2.0ms preprocess, 117.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.0ms
# Speed: 2.0ms preprocess, 135.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.3ms
# Speed: 3.7ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.1ms
# Speed: 3.0ms preprocess, 117.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.9ms
# Speed: 2.0ms preprocess, 120.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.3ms
# Speed: 2.0ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.7ms
# Speed: 2.0ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.7ms
# Speed: 3.0ms preprocess, 118.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2
from ultralytics import YOLO
model = YOLO("C:\\Users\\jithi\\Downloads\\yolov8Zip\\weights\\best.pt")
video_path = "C:\\Users\\jithi\\Downloads\\people walking.mp4"
cap = cv2.VideoCapture(video_path)
while cap.isOpened():
    success, frame = cap.read()
    if success:
        results = model(frame)
        annotated_frame = results[0].plot()
        cv2.imshow("YOLOv8 Inference", annotated_frame)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 7 persons, 125.4ms
# Speed: 4.0ms preprocess, 125.4ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 81.6ms
# Speed: 2.0ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 80.8ms
# Speed: 2.2ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 83.3ms
# Speed: 3.1ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 81.1ms
# Speed: 2.0ms preprocess, 81.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 76.8ms
# Speed: 3.0ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 78.5ms
# Speed: 2.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 75.1ms
# Speed: 2.3ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 73.5ms
# Speed: 2.4ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 73.8ms
# Speed: 2.4ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 75.5ms
# Speed: 1.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 79.3ms
# Speed: 2.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 84.3ms
# Speed: 2.1ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 74.9ms
# Speed: 2.0ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 73.5ms
# Speed: 2.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 74.2ms
# Speed: 1.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 78.8ms
# Speed: 2.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 74.6ms
# Speed: 1.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 75.9ms
# Speed: 2.3ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 73.3ms
# Speed: 3.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 75.6ms
# Speed: 3.0ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 69.5ms
# Speed: 2.0ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 73.6ms
# Speed: 2.2ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 69.5ms
# Speed: 2.1ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 72.7ms
# Speed: 1.0ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 74.7ms
# Speed: 2.3ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 73.4ms
# Speed: 2.0ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 73.4ms
# Speed: 2.0ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 71.7ms
# Speed: 2.3ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 73.2ms
# Speed: 2.5ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 73.9ms
# Speed: 2.0ms preprocess, 73.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 77.2ms
# Speed: 3.0ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 75.4ms
# Speed: 2.0ms preprocess, 75.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 91.1ms
# Speed: 4.2ms preprocess, 91.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 74.5ms
# Speed: 2.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 77.9ms
# Speed: 3.1ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 70.6ms
# Speed: 2.5ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 71.9ms
# Speed: 2.0ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 68.1ms
# Speed: 2.2ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 71.6ms
# Speed: 3.0ms preprocess, 71.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 73.9ms
# Speed: 2.5ms preprocess, 73.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 78.7ms
# Speed: 1.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 77.7ms
# Speed: 2.0ms preprocess, 77.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 74.5ms
# Speed: 2.3ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 70.1ms
# Speed: 3.6ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 74.7ms
# Speed: 3.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 72.9ms
# Speed: 2.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 74.1ms
# Speed: 2.0ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 71.8ms
# Speed: 3.0ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 89.3ms
# Speed: 2.2ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 74.4ms
# Speed: 3.5ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 73.7ms
# Speed: 2.5ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 73.1ms
# Speed: 3.0ms preprocess, 73.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 76.3ms
# Speed: 1.0ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 74.0ms
# Speed: 2.3ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 73.5ms
# Speed: 2.0ms preprocess, 73.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 74.1ms
# Speed: 2.0ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 74.2ms
# Speed: 2.3ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 72.3ms
# Speed: 1.0ms preprocess, 72.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 73.3ms
# Speed: 2.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 76.8ms
# Speed: 3.2ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 75.3ms
# Speed: 2.1ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 73.0ms
# Speed: 3.1ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 70.1ms
# Speed: 2.5ms preprocess, 70.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 75.0ms
# Speed: 2.1ms preprocess, 75.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 77.9ms
# Speed: 2.1ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 101.6ms
# Speed: 1.0ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 76.3ms
# Speed: 2.0ms preprocess, 76.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 74.1ms
# Speed: 2.0ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 73.3ms
# Speed: 2.0ms preprocess, 73.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 73.2ms
# Speed: 1.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons,
2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 80.9ms
# Speed: 4.0ms preprocess, 80.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 84.4ms
# Speed: 2.0ms preprocess, 84.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 76.6ms
# Speed: 3.0ms preprocess, 76.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 84.1ms
# Speed: 3.0ms preprocess, 84.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 94.5ms
# Speed: 2.2ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 100.8ms
# Speed: 2.3ms preprocess, 100.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 82.9ms
# Speed: 2.0ms preprocess, 82.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 81.4ms
# Speed: 2.0ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 75.8ms
# Speed: 2.1ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 74.9ms
# Speed: 2.0ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 80.8ms
# Speed: 2.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 81.3ms
# Speed: 2.0ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 88.5ms
# Speed: 3.1ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 82.2ms
# Speed: 2.1ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 82.0ms
# Speed: 1.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 76.4ms
# Speed: 2.0ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 76.6ms
# Speed: 2.0ms preprocess, 76.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 73.7ms
# Speed: 3.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 79.1ms
# Speed: 2.1ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 78.6ms
# Speed: 3.0ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 83.8ms
# Speed: 2.0ms preprocess, 83.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 78.4ms
# Speed: 2.0ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 76.3ms
# Speed: 3.0ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 75.3ms
# Speed: 2.3ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jithi\OneDrive\Desktop\VsCode\capstone\inference,.ipynb Cell 3 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jithi/OneDrive/Desktop/VsCode/capstone/inference%2C.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> success, frame = cap.read()
#       <a href='vscode-notebook-cell:/c%3A/Users/jithi/OneDrive/Desktop/VsCode/capstone/inference%2C.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> if success:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jithi/OneDrive/Desktop/VsCode/capstone/inference%2C.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     results = model(frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/jithi/OneDrive/Desktop/VsCode/capstone/inference%2C.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     annotated_frame = results[0].plot()
#      <a href='vscode-notebook-cell:/c%3A/Users/jithi/OneDrive/Desktop/VsCode/capstone/inference%2C.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     cv2.imshow("YOLOv8 Inference", annotated_frame)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\model.py:98, in Model.__call__(self, source, stream, **kwargs)
#      96 def __call__(self, source=None, stream=False, **kwargs):
#      97     """Calls the 'predict' function with given arguments to perform object detection."""
# ---> 98     return self.predict(source, stream, **kwargs)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\model.py:246, in Model.predict(self, source, stream, predictor, **kwargs)
#     244 if len and hasattr(self.predictor, 'set_prompts'):
#     245     self.predictor.set_prompts(prompts)
# --> 246 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:197, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     195     return self.stream_inference(source, model, *args, **kwargs)
#     196 else:
# --> 197     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\engine\predictor.py:138, in BasePredictor.inference(self, im, *args, **kwargs)
#     135 def inference(self, im, *args, **kwargs):
#     136     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     137                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 138     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\autobackend.py:334, in AutoBackend.forward(self, im, augment, visualize)
#     331     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     333 if self.pt or self.nn_module:  # PyTorch
# --> 334     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     335 elif self.jit:  # TorchScript
#     336     y = self.model(im)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\modules\block.py:180, in C2f.forward(self, x)
#     178 def forward(self, x):
#     179     """Forward pass through C2f layer."""
# --> 180     y = list(self.cv1(x).chunk(2, 1))
#     181     y.extend(m(y[-1]) for m in self.m)
#     182     return self.cv2(torch.cat(y, 1))
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\ultralytics\nn\modules\conv.py:42, in Conv.forward_fuse(self, x)
#      40 def forward_fuse(self, x):
#      41     """Perform transposed convolution of 2D data."""
# ---> 42     return self.act(self.conv(x))
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\jithi\.conda\envs\tensorflow_OIIO\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
